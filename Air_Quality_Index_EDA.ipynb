# %% [markdown]
# # Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# %%
city_day=r'C:\Users\gango\AQI-Analysis\DataSets\city_day.csv'
city_hour=r"C:\Users\gango\AQI-Analysis\DataSets\city_hour.csv"
station_day=r"C:\Users\gango\AQI-Analysis\DataSets\station_day.csv"
station_hour=r"C:\Users\gango\AQI-Analysis\DataSets\station_hour.csv"
stations=r"C:\Users\gango\AQI-Analysis\DataSets\stations.csv"

# %%
cday_df = pd.read_csv(city_day, parse_dates=['Date'])
chour_df = pd.read_csv(city_hour)
sday_df = pd.read_csv(station_day, parse_dates=['Date'])
shour_df = pd.read_csv(station_hour)
stations_df = pd.read_csv(stations)
# Out:
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\2388099882.py:4: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   shour_df = pd.read_csv(station_hour)

# %% [markdown]
# # Data Preprocessing

# %%
def dfInfo(df):
    '''
    Prints basic information such as shape, columns with missing values, etc about any input dataframe.

    Arguments:
        df(pandas DataFFrame)
    Returns:
        None
    '''
    print('='*50)
    print(f'Shape of the dataframe: {df.shape}')
    print('='*50)
    print(df.info())
    print('='*50)
    null_cols = [col for col in df.columns if df[col].isnull().sum() != 0]
    print(f'Columns with missing values: {null_cols}')

# %%
dfInfo(cday_df)
# Out:
# ==================================================
# Shape of the dataframe: (29531, 16)
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  datetime64[ns]
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 3.6+ MB
# None
# ==================================================
# Columns with missing values: ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']

# %% [markdown]
# *Observations*
# - There are 29531 rows and 16 columns.
# - The data type is correct for each feature.
# - There are missing values in columns: ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']

# %% [markdown]
# #### Check null percentage of the missing values in city_day table

# %%
def null_percents(df):
    null_percent = []
    for col in df.columns:
        null_percent.append(df[col].isnull().sum() * 100 / len(df))
    null_df = pd.DataFrame({"Columns":df.columns, "Null_Percent":null_percent})
    null_df = null_df.sort_values(by=['Null_Percent'], ascending=False)
    return null_df

# %%
# checking null percentage of each column in a dataframe
cday_nullpercent = null_percents(cday_df)

# %%
cday_nullpercent
# Out:
#        Columns  Null_Percent
# 13      Xylene     61.322001
# 3         PM10     37.723071
# 7          NH3     34.973418
# 12     Toluene     27.229014
# 11     Benzene     19.041008
# 14         AQI     15.851139
# 15  AQI_Bucket     15.851139
# 2        PM2.5     15.570079
# 6          NOx     14.171549
# 10          O3     13.619586
# 9          SO2     13.050692
# 5          NO2     12.139785
# 4           NO     12.129626
# 8           CO      6.972334
# 0         City      0.000000
# 1         Date      0.000000

# %%
cday_copy = cday_df.copy()
cday_copy.head(2)
# Out:
#         City       Date  PM2.5  PM10    NO    NO2    NOx  NH3    CO    SO2  \
# 0  Ahmedabad 2015-01-01    NaN   NaN  0.92  18.22  17.15  NaN  0.92  27.64
# 1  Ahmedabad 2015-01-02    NaN   NaN  0.97  15.69  16.46  NaN  0.97  24.55
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN

# %%
cday_copy['Xylene'].interpolate(method='linear', limit_direction="both", inplace=True)

# %%
cday_nullpcopy = null_percents(cday_copy)
cday_nullpcopy
# Out:
#        Columns  Null_Percent
# 3         PM10     37.723071
# 7          NH3     34.973418
# 12     Toluene     27.229014
# 11     Benzene     19.041008
# 14         AQI     15.851139
# 15  AQI_Bucket     15.851139
# 2        PM2.5     15.570079
# 6          NOx     14.171549
# 10          O3     13.619586
# 9          SO2     13.050692
# 5          NO2     12.139785
# 4           NO     12.129626
# 8           CO      6.972334
# 0         City      0.000000
# 1         Date      0.000000
# 13      Xylene      0.000000

# %%
cday_df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  11422.000000  24850.000000
# mean       8.700972      3.070128    166.463581
# std       19.969164      6.323247    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.140000     81.000000
# 50%        2.970000      0.980000    118.000000
# 75%        9.150000      3.350000    208.000000
# max      454.850000    170.370000   2049.000000

# %%
cday_copy.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  29531.000000  24850.000000
# mean       8.700972      3.399624    166.463581
# std       19.969164      5.617543    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.250000     81.000000
# 50%        2.970000      2.601738    118.000000
# 75%        9.150000      4.737919    208.000000
# max      454.850000    170.370000   2049.000000

# %%
cday_df['AQI_Bucket'].value_counts()
# Out:
# Moderate        8829
# Satisfactory    8224
# Poor            2781
# Very Poor       2337
# Good            1341
# Severe          1338
# Name: AQI_Bucket, dtype: int64

# %%
avg_cityaqi = cday_df.groupby(['City'])['AQI'].mean().reset_index()
avg_cityaqi = avg_cityaqi.sort_values(by=['AQI'], ascending=False)
avg_cityaqi[:5]
# Out:
#          City         AQI
# 0   Ahmedabad  452.122939
# 10      Delhi  259.487744
# 21      Patna  240.782042
# 12   Gurugram  225.123882
# 19    Lucknow  217.973059

# %%
plt.figure(figsize=(6,8))
sns.barplot(data=avg_cityaqi[:10], y='City', x='AQI', palette='Set2')
plt.xticks(rotation=45)
plt.show()

# %%
# yearly ahmedabad

avg_cityaqi = cday_df.groupby(['City'])['AQI'].mean().reset_index()

# %%
ahmedabad_hours = chour_df[chour_df['City']=='Ahmedabad']
ahmedabad_hours.drop(columns=['City'], inplace=True)
ahmedabad_hours.head(3)
# Out:
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\4114691368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ahmedabad_hours.drop(columns=['City'], inplace=True)
#               Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO     SO2  \
# 0  2015-01-01 01:00:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00  122.07
# 1  2015-01-01 02:00:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02   85.90
# 2  2015-01-01 03:00:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08   52.83
#
#    O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0 NaN      0.0      0.0     0.0  NaN        NaN
# 1 NaN      0.0      0.0     0.0  NaN        NaN
# 2 NaN      0.0      0.0     0.0  NaN        NaN

# %%
ahmedabad_hours['Datetime'] = pd.to_datetime(ahmedabad_hours['Datetime'])
dfInfo(ahmedabad_hours)
# Out:
# ==================================================
# Shape of the dataframe: (48192, 15)
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48192 entries, 0 to 48191
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Datetime    48192 non-null  datetime64[ns]
#  1   PM2.5       31129 non-null  float64
#  2   PM10        8929 non-null   float64
#  3   NO          31562 non-null  float64
#  4   NO2         32037 non-null  float64
#  5   NOx         32344 non-null  float64
#  6   NH3         0 non-null      float64
#  7   CO          31562 non-null  float64
#  8   SO2         28955 non-null  float64
#  9   O3          28863 non-null  float64
#  10  Benzene     34774 non-null  float64
#  11  Toluene     34771 non-null  float64
#  12  Xylene      34764 non-null  float64
#  13  AQI         30921 non-null  float64
#  14  AQI_Bucket  30921 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(1)
# memory usage: 5.9+ MB
# None
# ==================================================
# Columns with missing values: ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\3249209712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ahmedabad_hours['Datetime'] = pd.to_datetime(ahmedabad_hours['Datetime'])

# %%
ahmedabad_nulls = null_percents(ahmedabad_hours)
ahmedabad_nulls
# Out:
#        Columns  Null_Percent
# 6          NH3    100.000000
# 2         PM10     81.472029
# 9           O3     40.108317
# 8          SO2     39.917414
# 13         AQI     35.837898
# 14  AQI_Bucket     35.837898
# 1        PM2.5     35.406292
# 3           NO     34.507802
# 7           CO     34.507802
# 4          NO2     33.522161
# 5          NOx     32.885126
# 12      Xylene     27.863546
# 11     Toluene     27.849021
# 10     Benzene     27.842795
# 0     Datetime      0.000000

# %%
ahmedabad_hours['Year'] = ahmedabad_hours['Datetime'].dt.year
ahmedabad_yearlyaqi = ahmedabad_hours.groupby(['Year'])['AQI'].mean().reset_index()
ahmedabad_yearlyaqi
# Out:
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\3193463894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ahmedabad_hours['Year'] = ahmedabad_hours['Datetime'].dt.year
#    Year         AQI
# 0  2015  308.394104
# 1  2016  301.937944
# 2  2017  564.504348
# 3  2018  625.103687
# 4  2019  517.344423
# 5  2020  241.099326

# %%
sns.lineplot(data=ahmedabad_yearlyaqi, x='Year', y='AQI', color='#ff6961')
plt.title('Average AQI of Ahmedabad over the years')
plt.show()

# %% [markdown]
# #### Missing values count of AQI in Ahmedabad city over the years.

# %%
ahmedabad_yearlynull = ahmedabad_hours[ahmedabad_hours['AQI'].isnull()]
check_null = ahmedabad_yearlynull.groupby(['Year'])['Datetime'].count().reset_index()
check_null
# Out:
#    Year  Datetime
# 0  2015      2687
# 1  2016      6109
# 2  2017      7150
# 3  2018       379
# 4  2019       584
# 5  2020       362

# %%
plt.figure(figsize=(6,4))

sns.barplot(data=check_null, y='Datetime', x='Year', palette='Set2')
plt.ylabel('AQI Null Count')
plt.title('AQI Null Counts over the years')
plt.show()

# %%
ahmedabad_hours['Hours'] = ahmedabad_hours['Datetime'].dt.hour
ahmedabad_hours['Month'] = ahmedabad_hours['Datetime'].dt.month


ahmedabad_2018 = ahmedabad_hours[ahmedabad_hours['Year']==2018]
ahemdabad_2018 = ahmedabad_2018.drop(columns=['Year'], inplace=True)
# Out:
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\1565239453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ahmedabad_hours['Hours'] = ahmedabad_hours['Datetime'].dt.hour
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\1565239453.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ahmedabad_hours['Month'] = ahmedabad_hours['Datetime'].dt.month
# C:\Users\gango\AppData\Local\Temp\ipykernel_5108\1565239453.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ahemdabad_2018 = ahmedabad_2018.drop(columns=['Year'], inplace=True)

# %%
ahmedabad_2018
# Out:
#                  Datetime   PM2.5  PM10      NO     NO2     NOx  NH3      CO  \
# 26303 2018-01-01 00:00:00   78.43   NaN   23.79  126.91   79.66  NaN   23.79
# 26304 2018-01-01 01:00:00   77.60   NaN    7.71  105.18   57.06  NaN    7.71
# 26305 2018-01-01 02:00:00   74.23   NaN    5.13   71.65   38.78  NaN    5.13
# 26306 2018-01-01 03:00:00   63.43   NaN    5.36   62.14   34.32  NaN    5.36
# 26307 2018-01-01 04:00:00   64.57   NaN    5.04   64.52   35.23  NaN    5.04
# ...                   ...     ...   ...     ...     ...     ...  ...     ...
# 35058 2018-12-31 19:00:00   54.38   NaN   56.10  198.88   78.57  NaN   56.10
# 35059 2018-12-31 20:00:00   84.11   NaN  210.51  178.44  159.69  NaN  210.51
# 35060 2018-12-31 21:00:00  160.51   NaN  366.40   89.90  319.11  NaN  366.40
# 35061 2018-12-31 22:00:00  203.52   NaN  468.24     NaN  293.07  NaN  468.24
# 35062 2018-12-31 23:00:00  217.62   NaN  446.06     NaN  240.26  NaN  446.06
#
#           SO2     O3  Benzene  Toluene  Xylene     AQI AQI_Bucket  Hours  \
# 26303   74.95  24.63    11.18    40.92    3.21   340.0  Very Poor      0
# 26304     NaN  50.90    11.94    40.68    3.21   340.0  Very Poor      1
# 26305     NaN  86.82    11.63    34.19    3.21   340.0  Very Poor      2
# 26306  146.82  88.05    10.26    24.79    3.21   340.0  Very Poor      3
# 26307  117.86  87.30     7.39    21.28    3.21   340.0  Very Poor      4
# ...       ...    ...      ...      ...     ...     ...        ...    ...
# 35058  116.28  19.72     4.10    32.28    7.05   530.0     Severe     19
# 35059   77.61   7.67     3.97    32.42    6.81  1438.0     Severe     20
# 35060   76.70   8.95     3.97    32.37    6.88  2355.0     Severe     21
# 35061   60.38   6.34     4.13    32.37    6.86  2954.0     Severe     22
# 35062   76.38   6.59     3.97    32.41    6.92  2954.0     Severe     23
#
#        Month
# 26303      1
# 26304      1
# 26305      1
# 26306      1
# 26307      1
# ...      ...
# 35058     12
# 35059     12
# 35060     12
# 35061     12
# 35062     12
#
# [8760 rows x 17 columns]

# %%
avg_pollutants = ahmedabad_2018.groupby(['Month']).mean().reset_index()
avg_pollutants_new = avg_pollutants.copy()
avg_pollutants_new.drop(columns=['PM10', 'NH3', 'Hours'], inplace=True)

# %%
avg_pollutants_new
# Out:
#     Month       PM2.5         NO         NO2         NOx         CO  \
# 0       1   88.675230  32.195540  140.834603   94.427868  32.195540
# 1       2  103.768204  57.412554  157.843191  122.929340  57.412554
# 2       3   96.970713  34.478138  114.671961   86.291697  34.478138
# 3       4   82.533053  22.757889   62.190058   46.887007  22.757889
# 4       5   53.997694  12.199764   32.563771   24.525486  12.199764
# 5       6   56.118012  28.942744   45.381307   43.650172  28.942744
# 6       7   56.220368  27.766269   59.019227   49.528684  27.766269
# 7       8   41.815777  27.498951   54.575395   47.109905  27.498951
# 8       9   23.521590  31.005607   85.412249   64.803077  31.005607
# 9      10   96.716842  37.047978  100.471025   54.608479  37.047978
# 10     11  101.430126  53.807662   92.580411   57.302083  53.807662
# 11     12   91.920148  34.953163   81.978482   39.719772  34.953163
#
#            SO2         O3    Benzene    Toluene     Xylene         AQI
# 0   107.991594  52.094322  18.094728  71.944547  13.063570  690.421569
# 1   120.496310  40.919174   5.027865  32.172348   8.351609  959.590909
# 2    91.412615  50.722028  12.395688  51.708707  10.496954  783.368272
# 3    50.320000  44.091407   7.726705  32.081410   5.347496  559.161850
# 4    68.576850  33.765168   7.980861  31.998208   1.155931  322.962644
# 5    42.028537  14.279276   6.073793  47.643496   1.540632  428.513196
# 6    25.774885   2.617897   7.103514  40.955658   1.449824  453.788978
# 7    72.547810  12.785711   5.471839  25.663120   1.299755  465.616231
# 8    60.622407  35.100552   3.980311  16.533743   0.650000  557.982919
# 9    77.836222  55.422032   5.256505  20.599363  10.109597  697.305014
# 10   60.853782  53.159732  13.111500  41.475611  10.975486  955.341667
# 11   55.111152  53.801056   4.074180  32.328280   6.945551  665.370968

# %%
# fig, ax = plt.subplots(4,3,figsize=(15,8), sharey=True)
# ax[0,0].plot(x=avg_pollutants_new['Month'],y=avg_pollutants_new['PM2.5']) 
sns.lineplot( x=avg_pollutants_new['Month'], y=avg_pollutants_new['PM2.5'], label='PM2.5')
# ax[0,0].set_title('PM2.5')

sns.lineplot(x=avg_pollutants_new['Month'], y=avg_pollutants_new['NO'], label='NO')
# ax[0,1].set_title('NO')

sns.lineplot(x=avg_pollutants_new['Month'], y=avg_pollutants_new['NO2'], label='NO2')
# ax[0,2].set_title('NO2')

sns.lineplot(x=avg_pollutants_new['Month'], y=avg_pollutants_new['NOx'], label='NOx')
# ax[1,0].set_title('NOx')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='PM2.5'>

# %%
sns.lineplot(data=avg_pollutants, x='Month', y='AQI')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AQI'>

# %%
peakhours_2018 = ahmedabad_2018.groupby(['Hours'])['AQI'].mean().reset_index()
peakhours_2018 = peakhours_2018.sort_values(by=['AQI'], ascending=False)
peakhours_2018
# Out:
#     Hours         AQI
# 3       3  934.823362
# 2       2  925.086705
# 4       4  924.316239
# 1       1  920.861272
# 0       0  901.881159
# 23     23  885.864162
# 5       5  881.542614
# 22     22  828.887608
# 6       6  774.096866
# 21     21  730.092219
# 7       7  685.311429
# 8       8  626.626781
# 9       9  535.900285
# 20     20  518.773639
# 10     10  487.525714
# 11     11  456.037249
# 12     12  439.891429
# 13     13  431.705714
# 14     14  426.273504
# 15     15  411.404558
# 16     16  359.008571
# 19     19  324.550143
# 17     17  312.037249
# 18     18  290.681948

# %%
plt.figure(figsize=(6,4))
sns.lineplot(data=peakhours_2018, x='Hours', y='AQI', color='#ff6961')
plt.title('Average AQI over the hours in Ahmedabad')
plt.show()

# %%
aqibucket_2018 = ahmedabad_2018.groupby(['Hours', 'AQI_Bucket'])['AQI'].count()
aqibucket_2018
# Out:
# Hours  AQI_Bucket
# 0      Moderate       19
#        Poor           14
#        Severe        264
#        Very Poor      48
# 1      Moderate       18
#                     ...
# 22     Very Poor      54
# 23     Moderate       20
#        Poor           18
#        Severe        262
#        Very Poor      46
# Name: AQI, Length: 98, dtype: int64

# %%
aqi_3am = ahmedabad_2018[ahmedabad_2018['Hours']==3]
aqi_3am
# Out:
#                  Datetime   PM2.5  PM10      NO     NO2     NOx  NH3      CO  \
# 26306 2018-01-01 03:00:00   63.43   NaN    5.36   62.14   34.32  NaN    5.36
# 26330 2018-01-02 03:00:00   56.60   NaN    5.25   75.39   40.69  NaN    5.25
# 26354 2018-01-03 03:00:00   41.43   NaN    5.42   27.44   17.43  NaN    5.42
# 26378 2018-01-04 03:00:00   69.97   NaN    5.35   88.49   47.16  NaN    5.35
# 26402 2018-01-05 03:00:00   68.33   NaN    6.62  208.49  106.64  NaN    6.62
# ...                   ...     ...   ...     ...     ...     ...  ...     ...
# 34946 2018-12-27 03:00:00  105.67   NaN   91.09   93.89   73.07  NaN   91.09
# 34970 2018-12-28 03:00:00  179.34   NaN  119.01   77.80   84.79  NaN  119.01
# 34994 2018-12-29 03:00:00   70.76   NaN    7.09   60.39   18.32  NaN    7.09
# 35018 2018-12-30 03:00:00   61.31   NaN    6.71   38.77   12.96  NaN    6.71
# 35042 2018-12-31 03:00:00   63.43   NaN    6.83   43.71   14.21  NaN    6.83
#
#           SO2      O3  Benzene  Toluene  Xylene     AQI AQI_Bucket  Hours  \
# 26306  146.82   88.05    10.26    24.79    3.21   340.0  Very Poor      3
# 26330  103.38   48.02    11.25    52.48    3.21   186.0   Moderate      3
# 26354   59.19  112.60     4.44    21.55    3.21   511.0     Severe      3
# 26378   75.82     NaN    11.87    55.88    4.91   604.0     Severe      3
# 26402   65.28   13.71    13.74    38.28    3.21   549.0     Severe      3
# ...       ...     ...      ...      ...     ...     ...        ...    ...
# 34946  123.02   25.14     4.02    32.25    6.81  1407.0     Severe      3
# 34970   82.13   13.52     4.01    32.28    7.00  2780.0     Severe      3
# 34994   68.78   45.51     4.19    32.33    6.99   424.0     Severe      3
# 35018   54.46   65.66     4.01    32.25    6.99   637.0     Severe      3
# 35042   60.77   68.39     4.09    32.28    7.13   776.0     Severe      3
#
#        Month
# 26306      1
# 26330      1
# 26354      1
# 26378      1
# 26402      1
# ...      ...
# 34946     12
# 34970     12
# 34994     12
# 35018     12
# 35042     12
#
# [365 rows x 17 columns]

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=aqi_3am, x='Datetime', y='AQI', color='#ff6961')
plt.title('AQI over the year 2018 at 3AM in Ahmedabad')
plt.show()
